# %% [markdown]
# # Implementasi LDA

# %%
from sklearn.decomposition import LatentDirichletAllocation
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/ppw/PTA.csv')
df
# Out:
#     Unnamed: 0                                            Abstrak  \
# 0            0  sistem informasi akademik siakad merupakan sis...
# 1            1  berjalannya koneksi jaringan komputer dengan l...
# 2            2  web server adalah sebuah perangkat lunak serve...
# 3            3  penjadwalan kuliah di perguruan tinggi merupak...
# 4            4  seiring perkembangan teknologi yang ada diduni...
# 5            5  gerak pekerja ada pada game yang memiliki genr...
# 6            6  perkembangan game yang semakin pesat memberika...
# 7            7  sistem pengenalan wajah adalah suatu sistem un...
# 8            8  teknologi mobile game beroperating system open...
# 9            9  kantor badan kepegawaian kota bangkalan adalah...
# 10          10  penyusu sistem informasi dinas perindustrian p...
# 11          11  perusahaan pemerintah maupun swasta mempunyai ...
# 12          12  pelaya maka bagi pasien rawat inap di rumah sa...
# 13          13  penyusu sistem pendukung keputusan pemilihan t...
# 14          14  sidik jari adalah salah satu karakteristik fis...
# 15          15  di indonesia masalah perkembangan gizi adalah ...
# 16          16  pengenalan tulisan tangan merupakan topik pene...
# 17          17  citra senyum merupakan salah satu fitur biomet...
# 18          18  batik adalah keraji yang memiliki nilai seni t...
# 19          19  kebutuhan pencarian data pada internet yang ce...
# 20          20  dalam setiap perusahaan tentunya memiliki data...
# 21          21  citra digital banyak dimanfaatkan dalam berbag...
# 22          22  beasiswa adalah pemberian berupa bantuan keuan...
# 23          23  spare part merupakan salah satu bagian penting...
# 24          24  abstrak penjiplakan merupakan masalah yang ser...
# 25          25  sumber daya manusia mutlak dibutuhkan untuk ke...
# 26          26  abstrak data yang terdapat pada sma wachid has...
# 27          27  sebuah citra banyak diterapkan dalam berbagai ...
# 28          28  teknologi biometrik saat ini mengalami perkemb...
# 29          29  diagnosa penyakit mata dengan sistem informasi...
# 30          30  penggunaan teknologi mobile saat ini sangat ma...
# 31          31  setiap perusahaan mengharapkan adanya hubungan...
# 32          32  teknik kalibrasi sangat berpengaruh terhadap p...
# 33          33  pemilihan supplier merupakan salah satu isu pe...
# 34          34  kabupaten pamekasan merupakan salah satu pusat...
# 35          35  toko batik tulis madura merupakan salah satu t...
# 36          36  malaria disebabkan oleh intraseluler parasit b...
# 37          37  pt pos indonesia persero merupakan salah satu ...
# 38          38  deteksi manusia merupakan suatu aplikasi yang ...
# 39          39  aplikasi klasifikasi status gizi balita ini di...
# 40          40  penelitian ini membahas tentang perancangan si...
# 41          41  dengan prediksi yang baik dapat dibuat rencana...
# 42          42  menurut pemetaan yang dilakukan oleh tim nasio...
# 43          43  berawal dari permintaan akan straw sperma beku...
# 44          44  pengetahuan tentang bahasa inggris pada jaman ...
# 45          45  kabupaten bangkalan memiliki lahan pertanian s...
# 46          46  pengenalan tulisan tangan adalah salah satu ca...
# 47          47  batik merupakan seni yang paling penting dalam...
# 48          48  obat merupakan salah satu kebutuhan penting da...
# 49          49  abstrak perkembangan teknologi masa kini telah...
#
#                                        Abstrak_Tokens
# 0   ['sistem', 'informasi', 'akademik', 'siakad', ...
# 1   ['jalan', 'koneksi', 'jaring', 'komputer', 'la...
# 2   ['web', 'server', 'perangkat', 'lunak', 'serve...
# 3   ['jadwal', 'kuliah', 'guru', 'kompleks', 'masa...
# 4   ['iring', 'kembang', 'teknologi', 'dunia', 'mu...
# 5   ['gerak', 'kerja', 'game', 'milik', 'genre', '...
# 6   ['kembang', 'game', 'pesat', 'alternative', 'm...
# 7   ['sistem', 'kenal', 'wajah', 'sistem', 'nali',...
# 8   ['teknologi', 'mobile', 'game', 'beroperating'...
# 9   ['kantor', 'badan', 'pegawai', 'kota', 'bangka...
# 10  ['susu', 'sistem', 'informasi', 'dinas', 'indu...
# 11  ['usaha', 'perintah', 'swasta', 'tuju', 'capai...
# 12  ['pelaya', 'pasien', 'rawat', 'inap', 'rumah',...
# 13  ['susu', 'sistem', 'dukung', 'putus', 'pilih',...
# 14  ['sidik', 'jari', 'salah', 'karakteristik', 'f...
# 15  ['indonesia', 'kembang', 'gizi', 'perhati', 's...
# 16  ['kenal', 'tulis', 'tangan', 'topik', 'teliti'...
# 17  ['citra', 'senyum', 'salah', 'fitur', 'biometr...
# 18  ['batik', 'keraji', 'milik', 'nilai', 'seni', ...
# 19  ['butuh', 'cari', 'data', 'internet', 'cepat',...
# 20  ['usaha', 'milik', 'data', 'kait', 'giat', 'bi...
# 21  ['citra', 'digital', 'manfaat', 'aspek', 'hidu...
# 22  ['beasiswa', 'beri', 'bantu', 'uang', 'orang',...
# 23  ['spare', 'part', 'salah', 'operasi', 'mesin',...
# 24  ['abstrak', 'jiplak', 'muncul', 'kembang', 'bi...
# 25  ['sumber', 'daya', 'manusia', 'mutlak', 'butuh...
# 26  ['abstrak', 'data', 'sma', 'wachid', 'hasyim',...
# 27  ['citra', 'terap', 'aspek', 'hidup', 'bidang',...
# 28  ['teknologi', 'biometrik', 'alami', 'kembang',...
# 29  ['diagnosa', 'sakit', 'mata', 'sistem', 'infor...
# 30  ['guna', 'teknologi', 'mobile', 'marak', 'samp...
# 31  ['usaha', 'harap', 'hubung', 'langgan', 'pt', ...
# 32  ['teknik', 'kalibrasi', 'pengaruh', 'kembang',...
# 33  ['pilih', 'supplier', 'salah', 'isu', 'pilih',...
# 34  ['kabupaten', 'pamekasan', 'salah', 'pusat', '...
# 35  ['toko', 'batik', 'tulis', 'madura', 'salah', ...
# 36  ['malaria', 'sebab', 'intraseluler', 'parasit'...
# 37  ['pt', 'pos', 'indonesia', 'persero', 'salah',...
# 38  ['deteksi', 'manusia', 'aplikasi', 'fungsi', '...
# 39  ['aplikasi', 'klasifikasi', 'status', 'gizi', ...
# 40  ['teliti', 'bahas', 'ancang', 'sistem', 'infor...
# 41  ['prediksi', 'rencana', 'kerja', 'usaha', 'efe...
# 42  ['meta', 'tim', 'nasional', 'cepat', 'peggulan...
# 43  ['minta', 'straw', 'sperma', 'beku', 'sapi', '...
# 44  ['tahu', 'bahasa', 'inggris', 'jaman', 'global...
# 45  ['kabupaten', 'bangkal', 'milik', 'lahan', 'ta...
# 46  ['kenal', 'tulis', 'tangan', 'salah', 'cabang'...
# 47  ['batik', 'seni', 'hidup', 'masyarakat', 'indo...
# 48  ['obat', 'salah', 'butuh', 'rumah', 'sakit', '...
# 49  ['abstrak', 'kembang', 'teknologi', 'manusia',...

# %%
X = df.drop('Dokumen', axis=1)
X

# %%
k = 3
alpha = 0.1
beta = 0.2

lda = LatentDirichletAllocation(n_components=k, doc_topic_prior=alpha, topic_word_prior=beta)
proporsi_topik_dokumen = lda.fit_transform(X)

# %%
dokumen = df['Dokumen']
output_proporsi_TD = pd.DataFrame(proporsi_topik_dokumen, columns=['Topik 1', 'Topik 2', 'Topik 3'])
output_proporsi_TD.insert(0,'Dokumen', dokumen)
output_proporsi_TD

# %%
df.columns.shape

# %%
# Output distribusi kata pada topik
distribusi_kata_topik = pd.DataFrame(lda.components_)
distribusi_kata_topik
